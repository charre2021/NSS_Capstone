# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12251, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 12251 (delta 10), reused 14 (delta 8), pack-reused 12229
# Receiving objects: 100% (12251/12251), 11.94 MiB | 30.50 MiB/s, done.
# Resolving deltas: 100% (8480/8480), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 8.3 MB/s

# %%
import torch
import numpy as np
import utils
import yaml
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-252-g6a67594 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 38.8/166.8 GB disk)

# %%
# !python train.py --img 640 --batch 12 --epochs 20 --data '/content/drive/MyDrive/Colab Notebooks/pictures_for_models/data.yaml' --weights yolov5x.pt --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=/content/drive/MyDrive/Colab Notebooks/pictures_for_models/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=12, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-252-g6a67594 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# !python detect.py --iou-thres 0.5 --source '/content/drive/MyDrive/Colab Notebooks/pictures_for_models/images/test' --weights '/content/yolov5/runs/train/exp/weights/best.pt'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Colab Notebooks/pictures_for_models/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-252-g6a67594 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86180143 parameters, 0 gradients
# image 1/85 /content/drive/MyDrive/Colab Notebooks/pictures_for_models/images/test/pic_0.jpg: 640x544 1 tiny_hand, 1 normal_hand, Done. (0.033s)
# image 2/85 /content/drive/MyDrive/Colab Notebooks/pictures_for_models/images/test/pic_1.jpg: 384x640 1 tiny_hand, Done. (0.029s)
# ...
